# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# ## Analyze of Public Health data to analyze the People Health Condition based on Heart Rate and Oxygen Saturation

# %%
# Loading the data
public_health_data = pd.read_csv("Datasets\Raw\Rural_public_service_dataset.csv")
public_health_data.head()
# Out:
#           Region        Date  Oil Moisture  Blood Pressure  Heart Rate  \
# 0     Tamil Nadu  2024-01-01     18.981774      142.979403   62.923262
# 1         Kerala  2024-01-02     13.476998      104.325060   84.893731
# 2  Uttar Pradesh  2024-01-03     15.449762      104.275404   99.247113
# 3         Kerala  2024-01-04     18.837491      100.726509   67.604306
# 4         Kerala  2024-01-05     15.608580      157.390084   91.703805
#
#    Oxygen Saturation  Telemedicine Consultations         AQI  Water Levels  \
# 0          97.661459                           8  161.757324      4.302414
# 1          95.516325                           7   76.528030      1.240033
# 2          95.862619                           5  230.362909      2.504918
# 3          97.839871                           2  225.538376      4.702332
# 4          96.481788                           7  176.509707      3.012175
#
#    Temperature  Agriculture Target  Healthcare Target  Environmental Target
# ...

# %%
public_health_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Region                      1000 non-null   object
#  1   Date                        1000 non-null   object
#  2   Oil Moisture                1000 non-null   float64
#  3   Blood Pressure              1000 non-null   float64
#  4   Heart Rate                  1000 non-null   float64
#  5   Oxygen Saturation           1000 non-null   float64
#  6   Telemedicine Consultations  1000 non-null   int64
#  7   AQI                         1000 non-null   float64
#  8   Water Levels                1000 non-null   float64
#  9   Temperature                 1000 non-null   float64
#  10  Agriculture Target          1000 non-null   int64
#  11  Healthcare Target           1000 non-null   int64
#  12  Environmental Target        1000 non-null   int64
# ...

# %%
public_health_data.columns
# Out:
# Index(['Region', 'Date', 'Oil Moisture', 'Blood Pressure', 'Heart Rate',
#        'Oxygen Saturation', 'Telemedicine Consultations', 'AQI',
#        'Water Levels', 'Temperature', 'Agriculture Target',
#        'Healthcare Target', 'Environmental Target'],
#       dtype='object')

# %%
public_health_data.columns = public_health_data.columns.str.replace(" ","_")
public_health_data.columns = public_health_data.columns.str.lower()

# %% [markdown]
# ## Basic Information

# %%
# selecting only the necessary columns for our model
health_condition = public_health_data[['heart_rate','oxygen_saturation','healthcare_target']]
health_condition.head(10)
# Out:
#    heart_rate  oxygen_saturation  healthcare_target
# 0   62.923262          97.661459                  1
# 1   84.893731          95.516325                  0
# 2   99.247113          95.862619                  1
# 3   67.604306          97.839871                  0
# 4   91.703805          96.481788                  1
# 5   96.315952          99.691579                  1
# 6   97.748064          99.093701                  1
# 7   98.405424          99.917836                  1
# 8   80.858386          96.298354                  0
# 9   99.092316          99.848618                  1

# %%
health_condition['healthcare_target'].value_counts()
# Out:
# healthcare_target
# 0    502
# 1    498
# Name: count, dtype: int64

# %%
health_condition.isna().sum()
# Out:
# heart_rate           0
# oxygen_saturation    0
# healthcare_target    0
# dtype: int64

# %%
health_condition.duplicated().sum()
# Out:
# 0

# %%
print("\nSummary Statistics:\n", health_condition.describe())
# Out:
# Summary Statistics:
#          heart_rate  oxygen_saturation  healthcare_target
# count  1000.000000        1000.000000        1000.000000
# mean     79.933743          97.455405           0.498000
# std      11.513250           1.429677           0.500246
# min      60.000465          95.000154           0.000000
# 25%      69.900196          96.240596           0.000000
# 50%      80.082984          97.419558           0.000000
# 75%      89.934519          98.651143           1.000000
# max      99.982308          99.988747           1.000000

# %% [markdown]
# ## Data Vizualization

# %% [markdown]
# ### Data Histograms

# %%
# Visualizing Distributions
plt.figure(figsize=(12, 5))

# Histogram for Vizualize data
plt.subplot(1, 2, 1)
sns.histplot(health_condition["heart_rate"], bins=10, kde=True, color='blue')
plt.title("Heart Rate Distribution")

plt.subplot(1, 2, 2)
sns.histplot(health_condition["oxygen_saturation"], bins=10, kde=True, color='green')
plt.title("Oxygen Saturation Distribution")
# Out:
# Text(0.5, 1.0, 'Oxygen Saturation Distribution')

# %% [markdown]
# ### Detecting Outliers

# %%
# Boxplots to detect outliers
plt.figure(figsize=(10, 5))
sns.boxplot(data=health_condition[['heart_rate', 'oxygen_saturation']])
plt.title("Boxplot of Heart Rate and Oxygen Saturation")
plt.show()

# %% [markdown]
# ### Correlation Matrix

# %%
# Correlation Matrix
plt.figure(figsize=(6, 4))
sns.heatmap(health_condition.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ### Scatter Plot

# %%
#Heart Rate vs Oxygen Saturation (Emergency vs Normal)
plt.figure(figsize=(8, 6))
sns.scatterplot(x=health_condition["heart_rate"], y=health_condition["oxygen_saturation"], hue=health_condition["healthcare_target"], palette={0: "red", 1: "green"})
plt.title("Heart Rate vs Oxygen Saturation (Emergency vs Normal)")
plt.xlabel("Heart Rate")
plt.ylabel("Oxygen Saturation")
plt.legend(title="Healthcare Target", labels=["Normal (0)", "Emergency (1)"])
plt.show()

# %% [markdown]
# ##### These data are ready to feed into a ML model. As there aren't do much of pre-processing (no outliers, missing values)

# %%
# Saving the data to Analyzed file
health_condition.to_csv("Datasets/Analyzed/Analyzed_Health_Condition_Data_Base.csv",index=False)

# %% [markdown]
# ##### As theres only 2 features to predict the health condition, its quite low set of features, to set into a model to get predictions. Therefore we created some additional features as well.

# %% [markdown]
# ## Adding additional features to the Dataset

# %% [markdown]
# These are the new features that are adding to the Dataset
# 1. HR_02 Interaction
# 2. HR_02 Ratio

# %%
health_condition["hr_o2_interaction"] = health_condition["heart_rate"] * health_condition["oxygen_saturation"]
health_condition["hr_o2_ratio"] = health_condition["heart_rate"] / health_condition["oxygen_saturation"]
# Out:
# C:\Users\Sandin Maheeshakya\AppData\Local\Temp\ipykernel_31636\1693016532.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   health_condition["hr_o2_interaction"] = health_condition["heart_rate"] * health_condition["oxygen_saturation"]
# C:\Users\Sandin Maheeshakya\AppData\Local\Temp\ipykernel_31636\1693016532.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   health_condition["hr_o2_ratio"] = health_condition["heart_rate"] / health_condition["oxygen_saturation"]

# %%
health_condition.head()
# Out:
#    heart_rate  oxygen_saturation  healthcare_target  hr_o2_interaction  \
# 0   62.923262          97.661459                  1        6145.177643
# 1   84.893731          95.516325                  0        8108.737165
# 2   99.247113          95.862619                  1        9514.088264
# 3   67.604306          97.839871                  0        6614.396610
# 4   91.703805          96.481788                  1        8847.747045
#
#    hr_o2_ratio
# 0     0.644300
# 1     0.888788
# 2     1.035306
# 3     0.690969
# 4     0.950478

# %% [markdown]
# ### Correlation Heatmap on the added features

# %%
# Correlation Matrix
plt.figure(figsize=(6, 4))
sns.heatmap(health_condition.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %%
# Saving the additional features dataset to csv
health_condition.to_csv("Datasets/Analyzed/Analyzed_Health_Condition_Data_added_features.csv",index=False)
